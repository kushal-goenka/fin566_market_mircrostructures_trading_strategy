# %%
ls
# Out:
# Analysis of tick data.ipynb  backtestingResults/
# FINAL_REPORT.md              metrics/
# README.md                    ticks_201910/
# Team3Strategy/               trading_signals/
# automateBackTesting.sh

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
col_names = ['COLLECTION_TIME', 'SOURCE_TIME', 'SEQ_NUM', 'TICK_TYPE', 'MARKET_CENTER', 'PRICE', 'SIZE','SYMBOL']

# %%
files = glob.glob("ticks_201910/*")

# %%
uniqueSymbols = list(set([file.split("_")[2] for file in files]))

# %%
len(uniqueSymbols)
# Out:
# 51

# %%
files[0].split("_")
# Out:
# ['ticks', '201910/tick', 'PFE', '20191016.txt']

# %%
tickers = ["AMZN","AAPL","GOOG","FB"]

# %%
for ticker in tickers:
    filesList = glob.glob("ticks_201910/tick_"+ticker+"*")

    date = "20191008"

    ticker_data = pd.read_csv('ticks_201910/tick_{}_{}.txt'.format(ticker, date), 
                                        names=col_names, parse_dates=[0, 1])

    print(len(ticker_data))
# Out:
# 989
# 3842
# 476
# 2130

# %%
ticker_data.head()
# Out:
#                 COLLECTION_TIME                   SOURCE_TIME  SEQ_NUM  \
# 0 2019-10-08 13:30:01.488931072 2019-10-08 13:30:01.488905602    98015
# 1 2019-10-08 13:30:35.962691072 2019-10-08 13:30:35.962669101   155172
# 2 2019-10-08 13:30:46.253498880 2019-10-08 13:30:46.253259410   169365
# 3 2019-10-08 13:30:58.721264896 2019-10-08 13:30:58.721242316   183837
# 4 2019-10-08 13:31:11.517228032 2019-10-08 13:31:11.517203250   203066
#
#   TICK_TYPE MARKET_CENTER    PRICE  SIZE  SYMBOL
# 0         T           IEX  178.200   100     NaN
# 1         T           IEX  178.040   100     NaN
# 2         T           IEX  178.090   200     NaN
# 3         T           IEX  178.245   100     NaN
# 4         T           IEX  178.150   100     NaN

# %%
plt.plot(ticker_data['PRICE'])
# plt.plot(b['PRICE'])

# %%
ticker_data['PRICE']
# Out:
# 0      269.77
# 1      269.72
# 2      269.74
# 3      269.74
# 4      269.75
#         ...
# 164    265.49
# 165    265.51
# 166    265.51
# 167    265.54
# 168    265.55
# Name: PRICE, Length: 169, dtype: float64

# %%
base = c['PRICE'][0]
change3 = []
for price in c['PRICE']:
    percentageChange = (price-base)/base
    change3.append(percentageChange+100)

# %%
plt.plot(change)
plt.plot(change3)

# %%
base = b['PRICE'][0]
change2 = []
for price in b['PRICE']:
    percentageChange = (price-base)/base
    change2.append(percentageChange+100)

# %%
ticker = "AAPL"
filesList = glob.glob("ticks_201910/tick_"+ticker+"*")

date = "20191001"

b = pd.read_csv('ticks_201910/tick_{}_{}.txt'.format(ticker, date), 
                                    names=col_names, parse_dates=[0, 1])

b
# Out:
#                    COLLECTION_TIME                   SOURCE_TIME   SEQ_NUM  \
# 0    2019-10-01 12:04:15.787417088 2019-10-01 12:04:15.787361663     29074
# 1    2019-10-01 12:04:17.534033920 2019-10-01 12:04:17.533987442     29082
# 2    2019-10-01 12:18:28.372678912 2019-10-01 12:18:28.372637797     35033
# 3    2019-10-01 13:19:28.659406080 2019-10-01 13:19:28.659366093     66110
# 4    2019-10-01 13:19:34.267168000 2019-10-01 13:19:34.267134621     66312
# ...                            ...                           ...       ...
# 5028 2019-10-01 19:59:55.145789440 2019-10-01 19:59:55.145605040  19328478
# 5029 2019-10-01 19:59:55.353212928 2019-10-01 19:59:55.353196356  19332214
# 5030 2019-10-01 19:59:55.501129984 2019-10-01 19:59:55.501111670  19333098
# 5031 2019-10-01 19:59:56.107406080 2019-10-01 19:59:56.107387609  19340632
# 5032 2019-10-01 19:59:56.107529984 2019-10-01 19:59:56.107512660  19340634
#
#      TICK_TYPE MARKET_CENTER   PRICE  SIZE
# 0            T           IEX  225.34   100
# 1            T           IEX  225.34   100
# 2            T           IEX  225.22   100
# 3            T           IEX  225.09   100
# 4            T           IEX  225.09   100
# ...        ...           ...     ...   ...
# 5028         T           IEX  224.52   100
# 5029         T           IEX  224.49   100
# 5030         T           IEX  224.49   100
# 5031         T           IEX  224.48   100
# 5032         T           IEX  224.46    30
#
# [5033 rows x 7 columns]

# %%
ticker = "MSFT"
filesList = glob.glob("ticks_201910/tick_"+ticker+"*")

date = "20191001"

c = pd.read_csv('ticks_201910/tick_{}_{}.txt'.format(ticker, date), 
                                    names=col_names, parse_dates=[0, 1])

c
# Out:
#                    COLLECTION_TIME                   SOURCE_TIME   SEQ_NUM  \
# 0    2019-10-01 13:30:01.848916992 2019-10-01 13:30:01.848893337    101929
# 1    2019-10-01 13:30:03.538481920 2019-10-01 13:30:03.538459111    108516
# 2    2019-10-01 13:30:03.652286976 2019-10-01 13:30:03.652260557    108817
# 3    2019-10-01 13:30:04.338280960 2019-10-01 13:30:04.338035090    109670
# 4    2019-10-01 13:30:04.641500160 2019-10-01 13:30:04.641274930    109721
# ...                            ...                           ...       ...
# 3959 2019-10-01 19:59:25.994732032 2019-10-01 19:59:25.994710988  19181809
# 3960 2019-10-01 19:59:25.994747904 2019-10-01 19:59:25.994731022  19181810
# 3961 2019-10-01 19:59:40.267667968 2019-10-01 19:59:40.267651072  19243869
# 3962 2019-10-01 19:59:41.858088960 2019-10-01 19:59:41.857888330  19248127
# 3963 2019-10-01 19:59:56.322565120 2019-10-01 19:59:56.322546916  19342502
#
#      TICK_TYPE MARKET_CENTER    PRICE  SIZE
# 0            T           IEX  139.650   100
# 1            T           IEX  139.630     1
# 2            T           IEX  139.630     1
# 3            T           IEX  139.635     4
# 4            T           IEX  139.630     1
# ...        ...           ...      ...   ...
# 3959         T           IEX  137.025   298
# 3960         T           IEX  137.025   100
# 3961         T           IEX  137.025     5
# 3962         T           IEX  137.060   100
# 3963         T           IEX  137.050   100
#
# [3964 rows x 7 columns]

# %%
def plotSymbol(symbol):

# %%
dates = [
        '20191001', '20191002', '20191003', '20191004',
        '20191007', '20191008', '20191009', '20191010',
        '20191011', '20191014', '20191015', '20191016',
        '20191017', '20191018', '20191021', '20191022',
        '20191023', '20191024', '20191025', '20191028',
        '20191029', '20191030', '20191031', '20191101'   
        ]

# %%
# Correlation Visualization

# %%
corrMatrix = pd.read_csv("trading_signals/correlation_SPY.csv")

# %%
import seaborn as sns

# %%
corrMatrix = corrMatrix.set_index("Unnamed: 0")

# %%
plt.figure(figsize=(25,20))
snsPlot = sns.heatmap(corrMatrix.abs(),cmap = sns.cm.rocket_r)

# %%
snsPlot.savefig("SPYCorrMatrix.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-8932c92d2f71> in <module>
# ----> 1 snsPlot.savefig("SPYCorrMatrix.png")
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
corrMatrix[dates].iloc[0]
# Out:
# 20191001    0.954624
# 20191002    0.735464
# 20191003    0.934701
# 20191004    0.928421
# 20191007    0.669119
# 20191008    0.009469
# 20191009    0.342343
# 20191010    0.322692
# 20191011    0.826305
# 20191014   -0.348201
# 20191015    0.576287
# 20191016   -0.153170
# 20191017    0.461392
# 20191018    0.739172
# 20191021    0.549099
# 20191022    0.767113
# 20191023   -0.312128
# 20191024   -0.214939
# 20191025    0.786632
# 20191028    0.554032
# 20191029    0.242431
# 20191030   -0.346161
# 20191031    0.070136
# 20191101    0.720887
# Name: 0, dtype: float64

# %%
# How do you find the lead lag relationship if the times are not exact?

# %%
How to get
# Out:
#     20191001  20191002  20191003  20191004  20191007  20191008  20191009  \
# 0   0.954624  0.735464  0.934701  0.928421  0.669119  0.009469  0.342343
# 1  -0.458965  0.854189  0.925974  0.926695  0.080546  0.799762  0.588251
# 2   0.931413  0.366665  0.963461  0.829736 -0.679487  0.758800  0.414474
# 3   0.211804  0.915093  0.494341  0.942891  0.335928  0.602262 -0.106438
# 4   0.943459  0.919921  0.889208  0.846091 -0.661984  0.798019  0.126524
# 5   0.982854  0.729444  0.927332  0.840866  0.732130  0.422408 -0.253761
# 6   0.689895  0.137239  0.888797  0.934107 -0.673723  0.776785 -0.026748
# 7   0.977862  0.768090  0.894255  0.916312  0.847161  0.627950 -0.352210
# 8   0.400173  0.914440  0.878848  0.720656  0.859669  0.827692 -0.430951
# 9   0.967527  0.767134  0.928204  0.885480  0.571925  0.723539  0.027670
# 10  0.926783  0.268726  0.274580  0.838525  0.116249  0.357899  0.004114
# 11  0.418071  0.906959  0.729856  0.732677 -0.666552  0.777531  0.358529
# 12  0.842141  0.868090  0.923138  0.911480 -0.312051  0.840617  0.304790
# 13  0.918374  0.947702  0.956543  0.063809  0.203941  0.691805  0.408609
# 14  0.947439  0.938427  0.960179  0.865691  0.593850  0.804317 -0.531616
# 15  0.966279  0.744085  0.951947  0.889613  0.197683  0.506643 -0.200449
# 16  0.972167  0.881538  0.822730  0.981942  0.387589  0.798728 -0.030503
# 17  0.793128  0.883727  0.650286  0.715094  0.412245  0.522874  0.223910
# 18  0.826064  0.772332  0.878049  0.715396  0.057038  0.845796  0.158376
# 19  0.951633  0.837847  0.921067  0.480562  0.749759  0.434091 -0.288806
# 20  0.963428  0.904617  0.970092  0.714576  0.617395  0.449524  0.127190
# 21  0.898994  0.925150  0.535285  0.896323  0.613723  0.661490 -0.270761
# 22 -0.014070 -0.015324  0.752769  0.914249  0.389821  0.017292 -0.711364
# 23  0.937435  0.462115  0.930138  0.877344  0.623027  0.563610 -0.199117
# 24  0.925861  0.805742  0.903084  0.944947  0.630596  0.739941 -0.025196
# 25 -0.385784  0.874203  0.945165  0.792664  0.714665  0.827932 -0.518874
# 26  0.793196  0.955730  0.963077  0.865377  0.598341  0.654256  0.435112
# 27  0.766254  0.706822  0.913275  0.867911 -0.263086  0.478662 -0.421045
# 28  0.975449  0.080658  0.846501 -0.020393  0.347315  0.211790  0.068231
#
#     20191010  20191011  20191014  ...  20191021  20191022  20191023  20191024  \
# 0   0.322692  0.826305 -0.348201  ...  0.549099  0.767113 -0.312128 -0.214939
# 1   0.538689  0.561106  0.193534  ...  0.098853 -0.247753 -0.217826 -0.408215
# 2   0.635357  0.675152 -0.500191  ...  0.463173  0.058067 -0.466636  0.645019
# 3   0.296049  0.687025  0.125287  ...  0.408010  0.310253  0.339240  0.159318
# 4   0.525814  0.692006  0.020853  ... -0.048060  0.644460  0.387290  0.595385
# 5   0.626960  0.499272 -0.006090  ...  0.415381  0.639852 -0.060812  0.521708
# 6   0.693217  0.473179  0.014037  ...  0.229434  0.603973 -0.448870  0.329010
# 7   0.808317  0.919373  0.284797  ...  0.405874  0.391955  0.555624  0.416168
# 8   0.415800  0.210629  0.512879  ...  0.266596 -0.221854  0.860079 -0.058911
# 9   0.574158  0.694893 -0.554899  ...  0.273343  0.255274 -0.636620  0.556669
# 10  0.720237  0.649907 -0.015652  ... -0.556302  0.714308  0.529527  0.369506
# 11  0.834301  0.437458  0.240239  ...  0.209494  0.358507  0.870549 -0.279591
# 12  0.451216  0.548814  0.531232  ...  0.391950  0.692315  0.837136  0.426162
# 13  0.641638  0.880757  0.640854  ...  0.040016  0.475503  0.478922 -0.032474
# 14  0.817558  0.842280 -0.204494  ...  0.376060  0.526916  0.259686  0.193923
# 15  0.727316  0.516964  0.136705  ...  0.423248 -0.345699 -0.035549  0.101438
# 16  0.564664  0.787066  0.274137  ...  0.489699  0.443281 -0.112591  0.839942
# 17  0.533785  0.430061  0.296973  ... -0.288493  0.609909  0.731692 -0.026309
# 18  0.739333  0.244409 -0.015314  ...  0.326695  0.602573 -0.636669  0.258770
# 19  0.256747  0.576920  0.197450  ...  0.413669  0.626374  0.307796 -0.088984
# 20 -0.103273  0.532665  0.586469  ...  0.234974  0.564421  0.654371  0.312421
# 21  0.624622  0.598492 -0.459709  ... -0.236835  0.293232  0.552979  0.507375
# 22  0.613192  0.276468  0.300012  ...  0.711306  0.336142  0.701217 -0.001207
# 23  0.501400  0.698070  0.195667  ...  0.646893  0.742888  0.425549  0.374409
# 24  0.848134  0.896149 -0.372702  ... -0.130750  0.649204  0.628824  0.616415
# 25  0.701201  0.429644  0.436639  ...  0.680266  0.196231  0.895890  0.539299
# 26  0.638345  0.434095  0.319963  ... -0.231522  0.556152  0.374270  0.775166
# 27  0.377344  0.253184  0.009113  ... -0.197113  0.245132 -0.416335  0.685660
# 28  0.337008  0.543266  0.217886  ... -0.513258  0.734133 -0.542532  0.586496
#
#     20191025  20191028  20191029  20191030  20191031  20191101
# 0   0.786632  0.554032  0.242431 -0.346161  0.070136  0.720887
# 1  -0.408082  0.143970  0.127113  0.427403  0.147057 -0.624132
# 2   0.816955  0.543095 -0.189723  0.913421  0.826195  0.642430
# 3  -0.156731  0.425856  0.705284  0.602682  0.737257  0.306739
# 4   0.091641  0.582211 -0.232923  0.513122  0.417838  0.582738
# 5   0.631659 -0.475718  0.770180  0.642419  0.862415  0.703359
# 6  -0.000006  0.648743  0.619863  0.585276  0.164414 -0.643626
# 7   0.723329  0.520747 -0.196205  0.906436  0.673190  0.168442
# 8  -0.132283  0.282067 -0.069225  0.766580  0.830554 -0.468489
# 9   0.584906  0.024228  0.457128  0.388032  0.733106  0.775249
# 10  0.388964  0.456566 -0.134172 -0.038699  0.163343  0.658168
# 11  0.795569  0.484399  0.499090  0.233374  0.232343 -0.629905
# 12  0.807343  0.440081  0.127731  0.813435  0.811890 -0.003574
# 13 -0.258085  0.418829 -0.156181  0.818437  0.810059  0.520082
# 14  0.690118  0.033320 -0.360234  0.825020 -0.365046 -0.100658
# 15 -0.084485 -0.020336 -0.471835  0.857246  0.655032 -0.174195
# 16  0.845387 -0.357890 -0.119146  0.393302  0.228518  0.717305
# 17 -0.328738  0.166276  0.111542  0.224502 -0.117776 -0.513096
# 18  0.751100 -0.046382  0.274012 -0.003429  0.315582 -0.590466
# 19  0.808013  0.514297  0.428269 -0.473142  0.219903  0.160927
# 20  0.649718  0.326909  0.480360  0.726830 -0.066967 -0.417516
# 21 -0.042143  0.473142  0.519913  0.607244 -0.190221  0.093459
# 22  0.544875  0.382014  0.371924  0.784913  0.607957 -0.674815
# 23  0.275233  0.628223 -0.326142  0.708195  0.896951 -0.595799
# 24  0.901848  0.125794 -0.012196  0.515674  0.583927  0.635733
# 25 -0.118571 -0.374347 -0.079931  0.871338  0.579182  0.067233
# 26  0.766178 -0.140422 -0.646786  0.417302  0.077627  0.809675
# 27  0.784248  0.626784  0.660431  0.104895  0.828365  0.670999
# 28  0.700006  0.219248  0.639119  0.868409  0.643023  0.472068
#
# [29 rows x 24 columns]

# %%
sns.heatmap(corrMatrix)
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-72-5ee8fa8c25de> in <module>
# ----> 1 sns.heatmap(corrMatrix)
#
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     546                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 547                           yticklabels, mask)
#     548
#     549     # Add the pcolormesh kwargs here
#
# /usr/local/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     164         # Determine good default values for the colormapping
#     165         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 166                                     cmap, center, robust)
#     167
#     168         # Sort out the annotations
#
# /usr/local/lib/python3.7/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     197
#     198         # plot_data is a np.ma.array instance
# --> 199         calc_data = plot_data.astype(float).filled(np.nan)
#     200         if vmin is None:
#     201             if robust:
#
# ValueError: could not convert string to float: 'XOM'

# %%
# -*- coding: utf-8 -*-
"""
@file: correlation.py
@author: Yong Xie
@time: 12/7/2020 12:01 PM
@Description: 

This cript is used to generate pairwise correlation between component and eft

"""

import pandas as pd
import matplotlib.pyplot as plt
import os

col_names = ['COLLECTION_TIME', 'SOURCE_TIME', 'SEQ_NUM', 'TICK_TYPE', 'MARKET_CENTER', 'PRICE', 'SIZE']

def comp_corr(input_folder, output_folder, dates, etf_ticker, comp_ticker):
    """

    # Calculate correlation between components and eft price

    Args:
        input_folder (str): tick data folder
        output_folder ([type]): output folder
        dates (list of str): yyyymmdd
        etf_ticker (str): ticker for etf of interest
        comp_ticker (list of ticker): component tickers
    Returns:
        csv file with each row represent correlation of corresponding ticker with eft
        and each column represent the date.

    """

    correlations = {}
    for date in dates:

        date_corr = {}

        etf = pd.read_csv(os.path.join(input_folder, 'tick_{}_{}.txt'.format(etf_ticker, date)), 
                                    names=col_names, parse_dates=[0, 1])

        for ticker in tickers:
            comp = pd.read_csv(os.path.join(input_folder, 'tick_{}_{}.txt'.format(ticker, date)), 
                                        names=col_names, parse_dates=[0, 1])

            combine = pd.merge(left=etf, right=comp, left_on='COLLECTION_TIME', right_on='COLLECTION_TIME', how='outer')
            combine = combine.sort_values('COLLECTION_TIME')

            combine = combine.fillna(method='pad', axis=0)
            corr = combine[['PRICE_x', 'PRICE_y']].corr()
            date_corr[ticker] = corr.iloc[1,0]
        correlations[date] = date_corr

        print('finished {}'.format(date))

    pd.DataFrame(correlations).to_csv(os.path.join(output_folder, 'correlation_{}.csv'.format(etf_ticker)))


if __name__ == '__main__':
    
    tickers = [
        'XOM', 'KO', 'IBM', 'PG', 'UTX', 'MMM', 'MRK', 'AXP', 'MCD', 'CAT', 
        'DIS', 'JNJ', 'WMT', 'HD', 'INTC', 'MSFT', 'JPM', 'VZ', 'PFE', 
        'CVX', 'CSCO', 'TRV', 'UNH', 'NKE', 'GS', 'V', 'AAPL', 'WBA', 'DOW'
        ]

    weights = [1] * len(tickers)

    input_folder = 'ticks_201910/'
    output_folder = 'ticks_201910/'
    dates = [
        '20191001', '20191002', '20191003', '20191004',
        '20191007', '20191008', '20191009', '20191010',
        '20191011', '20191014', '20191015', '20191016',
        '20191017', '20191018', '20191021', '20191022',
        '20191023', '20191024', '20191025', '20191028',
        '20191029', '20191030', '20191031', '20191101'   
        ]
    comp_corr(input_folder, output_folder, dates, 'SPY', tickers)
# Out:
# finished 20191001
# finished 20191002
# finished 20191003
# finished 20191004
# finished 20191007
# finished 20191008
# finished 20191009
# finished 20191010
# finished 20191011
# finished 20191014
# finished 20191015
# finished 20191016
# finished 20191017
# finished 20191018
# finished 20191021
# finished 20191022
# finished 20191023
# finished 20191024
# finished 20191025
# finished 20191028
# finished 20191029
# finished 20191030
# finished 20191031
# finished 20191101
